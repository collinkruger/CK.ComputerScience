# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])

# %%
pd.plotting.scatter_matrix(df, alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='A', ylabel='A'>,
#         <AxesSubplot:xlabel='B', ylabel='A'>,
#         <AxesSubplot:xlabel='C', ylabel='A'>,
#         <AxesSubplot:xlabel='D', ylabel='A'>],
#        [<AxesSubplot:xlabel='A', ylabel='B'>,
#         <AxesSubplot:xlabel='B', ylabel='B'>,
#         <AxesSubplot:xlabel='C', ylabel='B'>,
#         <AxesSubplot:xlabel='D', ylabel='B'>],
#        [<AxesSubplot:xlabel='A', ylabel='C'>,
#         <AxesSubplot:xlabel='B', ylabel='C'>,
#         <AxesSubplot:xlabel='C', ylabel='C'>,
#         <AxesSubplot:xlabel='D', ylabel='C'>],
#        [<AxesSubplot:xlabel='A', ylabel='D'>,
#         <AxesSubplot:xlabel='B', ylabel='D'>,
#         <AxesSubplot:xlabel='C', ylabel='D'>,
#         <AxesSubplot:xlabel='D', ylabel='D'>]], dtype=object)

# %%
pd.DataFrame.describe(df)
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.053459    -0.045071     0.005737     0.003537
# std       1.015184     0.980858     0.963465     1.008190
# min      -3.671936    -3.447797    -2.561008    -4.207991
# 25%      -0.640776    -0.697668    -0.659689    -0.634814
# 50%       0.084210    -0.044798    -0.008928     0.052106
# 75%       0.773445     0.617114     0.652685     0.641828
# max       3.022043     3.650032     2.931316     3.037930

# %%
pd.DataFrame(["a", "a","a","a","a", "b", "c"]).describe()
# Out:
#         0
# count   7
# unique  3
# top     a
# freq    5

# %%
pd.DataFrame([1, 1, 1, 1, 2, 3, 5]).describe()
# Out:
#               0
# count  7.000000
# mean   2.000000
# std    1.527525
# min    1.000000
# 25%    1.000000
# 50%    1.000000
# 75%    2.500000
# max    5.000000

# %%
# my_df = pd.DataFrame({ "a": [1, 1, 1, 1, 2, 3, 5] })
my_df = pd.DataFrame()
# my_df["b"] = my_df["a"].astype("category")
# my_df["c"] = [9, 8, 7, 6, 5, 4, 3]
my_df["d"] = pd.Series([9, 8, 7, 6, 5, 4, 3], dtype="category")
my_df["e"] = pd.Series([9, 8, 7, 6, 5, 4, 3], dtype="category")
my_df["c"] = [9, 8, 7, 6, 5, 4, 3]

display(my_df)
display(my_df.describe())
my_df["d"].describe()
# Out:
#    d  e  c
# 0  9  9  9
# 1  8  8  8
# 2  7  7  7
# 3  6  6  6
# 4  5  5  5
# 5  4  4  4
# 6  3  3  3
#               c
# count  7.000000
# mean   6.000000
# std    2.160247
# min    3.000000
# 25%    4.500000
# 50%    6.000000
# 75%    7.500000
# max    9.000000
# count     7
# unique    7
# top       3
# freq      1
# Name: d, dtype: int64

# %%
cat_df = my_df.select_dtypes(include=["category"])
display(cat_df)
display(cat_df.describe())
# Out:
#    d  e
# 0  9  9
# 1  8  8
# 2  7  7
# 3  6  6
# 4  5  5
# 5  4  4
# 6  3  3
#         d  e
# count   7  7
# unique  7  7
# top     3  3
# freq    1  1
